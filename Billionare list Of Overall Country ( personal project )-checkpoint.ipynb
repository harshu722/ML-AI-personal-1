# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud, STOPWORDS

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Forbes_Billionaires.csv')
df.head()
# Out:
#                        Name  NetWorth        Country         Source  Rank  \
# 0                Jeff Bezos     177.0  United States         Amazon     1
# 1                 Elon Musk     151.0  United States  Tesla, SpaceX     2
# 2  Bernard Arnault & family     150.0         France           LVMH     3
# 3                Bill Gates     124.0  United States      Microsoft     4
# 4           Mark Zuckerberg      97.0  United States       Facebook     5
#
#     Age              Residence    Citizenship           Status  Children  \
# 0  57.0    Seattle, Washington  United States  In Relationship       4.0
# 1  49.0          Austin, Texas  United States  In Relationship       7.0
# 2  72.0          Paris, France         France          Married       5.0
# 3  65.0     Medina, Washington  United States         Divorced       3.0
# 4  36.0  Palo Alto, California  United States          Married       2.0
#
#                                            Education Self_made
# 0     Bachelor of Arts/Science, Princeton University      True
# 1  Bachelor of Arts/Science, University of Pennsy...      True
# 2  Bachelor of Arts/Science, Ecole Polytechnique ...     False
# 3                       Drop Out, Harvard University      True
# 4                       Drop Out, Harvard University      True

# %%
df.shape
# Out:
# (2755, 12)

# %%
df.describe()
# Out:
#           NetWorth         Rank         Age     Children
# count  2755.000000  2755.000000  2630.00000  1552.000000
# mean      4.749220  1345.663521    63.26730     2.978093
# std       9.615358   772.669811    13.47916     1.618569
# min       1.000000     1.000000    18.00000     1.000000
# 25%       1.500000   680.000000    54.00000     2.000000
# 50%       2.300000  1362.000000    63.00000     3.000000
# 75%       4.200000  2035.000000    73.00000     4.000000
# max     177.000000  2674.000000    99.00000    23.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2755 entries, 0 to 2754
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         2755 non-null   object
#  1   NetWorth     2755 non-null   float64
#  2   Country      2755 non-null   object
#  3   Source       2755 non-null   object
#  4   Rank         2755 non-null   int64
#  5   Age          2630 non-null   float64
#  6   Residence    2715 non-null   object
#  7   Citizenship  2739 non-null   object
#  8   Status       2090 non-null   object
#  9   Children     1552 non-null   float64
#  10  Education    1409 non-null   object
#  11  Self_made    2737 non-null   object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 258.4+ KB

# %%
df.isnull().sum()
# Out:
# Name              0
# NetWorth          0
# Country           0
# Source            0
# Rank              0
# Age             125
# Residence        40
# Citizenship      16
# Status          665
# Children       1203
# Education      1346
# Self_made        18
# dtype: int64

# %%
plt.style.use('dark_background')

# %%
plt.figure(figsize=(20,8))
sns.countplot( data=df, x="Country", order=df['Country'].value_counts().index)
plt.xticks(rotation=90)
plt.ylabel("No of Billionaires", fontsize=25,color='blue')
plt.xlabel("Countries", fontsize=25,color='blue')
plt.title("No of Billionaires From All The Countries", fontsize=30,weight='bold',color='red')
plt.show()

# %%
plt.figure(figsize=(15,15))
sns.barplot( data=df, x="Networth",y='Country', order=df['Country'].value_counts().index,estimator=sum,errwidth=0)
plt.xticks(rotation=90)
plt.ylabel("Countries", fontsize=25,color='blue')
plt.xlabel("Networth", fontsize=25,color='blue')
plt.title("Is the country with the most billionaires the one with the most wealth?", fontsize=20,weight='bold',color='red')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7896\2669864161.py in <module>
#       1 plt.figure(figsize=(15,15))
# ----> 2 sns.barplot( data=df, x="Networth",y='Country', order=df['Country'].value_counts().index,estimator=sum,errwidth=0)
#       3 plt.xticks(rotation=90)
#       4 plt.ylabel("Countries", fontsize=25,color='blue')
#       5 plt.xlabel("Networth", fontsize=25,color='blue')
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3180 ):
#    3181
# -> 3182     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3183                           estimator, ci, n_boot, units, seed,
#    3184                           orient, color, palette, saturation,
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1582                  errwidth, capsize, dodge):
#    1583         """Initialize the plotter."""
# -> 1584         self.establish_variables(x, y, hue, data, orient,
#    1585                                  order, hue_order, units)
#    1586         self.establish_colors(color, palette, saturation)
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     151                 if isinstance(var, str):
#     152                     err = "Could not interpret input '{}'".format(var)
# --> 153                     raise ValueError(err)
#     154
#     155             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'Networth'

# %%
plt.figure(figsize=(15,15))
sns.barplot(x='NetWorth', y='Country', data=df, order=df['Country'].value_counts().index, estimator=sum, errwidth=0)
plt.xticks(rotation=90)
plt.ylabel("Countries", fontsize=25,color='blue')
plt.xlabel("Networth", fontsize=25,color='blue')
plt.title("Is the country with the most billionaires the one with the most wealth?", fontsize=20,weight='bold',color='red')
plt.show()

# %%
plt.figure(figsize = (15,8))
sns.histplot(data = df, x = 'Age', color = 'green')
plt.title('Age distribution of the billionaires',fontsize=20,color='red',weight='bold')
plt.show()

# %%
df.loc[df.Age==df.Age.min()]
# Out:
#                     Name  NetWorth  Country      Source  Rank   Age Residence  \
# 940  Kevin David Lehmann       3.3  Germany  drugstores   925  18.0       NaN
#
#     Citizenship Status  Children Education Self_made
# 940     Germany    NaN       NaN       NaN     False

# %%
df.loc[df.Age==df.Age.max()]
# Out:
#                Name  NetWorth        Country     Source  Rank   Age  \
# 1611  George Joseph       2.0  United States  insurance  1580  99.0
#
#                     Residence    Citizenship   Status  Children  \
# 1611  Los Angeles, California  United States  Married       5.0
#
#                                          Education Self_made
# 1611  Bachelor of Arts/Science, Harvard University      True

# %%
df['age_group'] = pd.cut(df['Age'], bins = [18, 30, 50, 70, 100], include_lowest = True, labels = ['18-30', '30-50', '50-70','70+'])
df.head()
# Out:
#                        Name  NetWorth        Country         Source  Rank  \
# 0                Jeff Bezos     177.0  United States         Amazon     1
# 1                 Elon Musk     151.0  United States  Tesla, SpaceX     2
# 2  Bernard Arnault & family     150.0         France           LVMH     3
# 3                Bill Gates     124.0  United States      Microsoft     4
# 4           Mark Zuckerberg      97.0  United States       Facebook     5
#
#     Age              Residence    Citizenship           Status  Children  \
# 0  57.0    Seattle, Washington  United States  In Relationship       4.0
# 1  49.0          Austin, Texas  United States  In Relationship       7.0
# 2  72.0          Paris, France         France          Married       5.0
# 3  65.0     Medina, Washington  United States         Divorced       3.0
# 4  36.0  Palo Alto, California  United States          Married       2.0
#
#                                            Education Self_made age_group
# 0     Bachelor of Arts/Science, Princeton University      True     50-70
# 1  Bachelor of Arts/Science, University of Pennsy...      True     30-50
# 2  Bachelor of Arts/Science, Ecole Polytechnique ...     False       70+
# 3                       Drop Out, Harvard University      True     50-70
# 4                       Drop Out, Harvard University      True     30-50

# %%
df['age_group'].value_counts().plot(kind='bar', figsize=(9,6))
plt.xlabel("Age Group", fontsize=15)
plt.ylabel("Billionaires Count", fontsize=15)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.barplot(data=df, x = "NetWorth", y = "Industry", order = df['Industry'].value_counts().index, estimator = sum , errwidth = 0)
plt.xticks(rotation=90)
plt.xlabel("Networth", fontsize=15)
plt.ylabel("Industries", fontsize=15)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Industry'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7896\3137983599.py in <module>
#       1 plt.figure(figsize=(15,8))
# ----> 2 sns.barplot(data=df, x = "NetWorth", y = "Industry", order = df['Industry'].value_counts().index, estimator = sum , errwidth = 0)
#       3 plt.xticks(rotation=90)
#       4 plt.xlabel("Networth", fontsize=15)
#       5 plt.ylabel("Industries", fontsize=15)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Industry'

# %%
stopwords = set(STOPWORDS)
text = " ".join(i for i in df.Source) 

plt.figure( figsize=(15,10))
wordcloud = WordCloud(
                      stopwords=stopwords,
                      max_words=200,
                      max_font_size=50, 
                      random_state=50
                     ).generate(text)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ## TOP 5 BILLIONARES OF INDIA

# %%
indians = df[df['Country'] == 'India']
top_5_indians = indians.sort_values('NetWorth',ascending=False).head()
df.loc[df['Name'].isin(top_5_indians['Name'])]
# Out:
#                       Name  NetWorth Country                       Source  \
# 9            Mukesh Ambani      84.5   India                  diversified
# 23   Gautam Adani & family      50.5   India  infrastructure, commodities
# 71              Shiv Nadar      23.5   India            software services
# 116     Radhakishan Damani      16.5   India          retail, investments
# 122             Uday Kotak      15.9   India                      banking
#
#      Rank   Age         Residence Citizenship   Status  Children  \
# 9      10  64.0     Mumbai, India       India  Married       3.0
# 23     24  58.0  Ahmedabad, India       India  Married       2.0
# 71     71  75.0      Delhi, India       India  Married       1.0
# 116   117  66.0     Mumbai, India       India  Married       3.0
# 122   121  62.0     Mumbai, India       India  Married       2.0
#
#                                              Education Self_made age_group
# 9    Drop Out, Stanford University; Bachelor of Sci...     False     50-70
# 23                                                 NaN      True     50-70
# 71   Bachelor of Arts/Science, PSG College of Techn...      True       70+
# 116                                                NaN      True     50-70
# 122  Bachelor of Arts/Science, Bombay University; M...      True     50-70

# %%
# declaring exploding pie
explode = [0.1, 0.01, 0, 0, 0]
# define Seaborn color palette to use
palette_color = sns.color_palette('dark')
  
# plotting data on chart
plt.pie(top_5_indians['NetWorth'], labels=top_5_indians['Name'], colors=palette_color,
        explode=explode, autopct='%.0f%%')
  
# displaying chart
plt.show()

# %%
us_df = df[df['Country'] == 'United States'].sort_values('NetWorth',ascending=False).head()
us_df
# Out:
#               Name  NetWorth        Country              Source  Rank   Age  \
# 0       Jeff Bezos     177.0  United States              Amazon     1  57.0
# 1        Elon Musk     151.0  United States       Tesla, SpaceX     2  49.0
# 3       Bill Gates     124.0  United States           Microsoft     4  65.0
# 4  Mark Zuckerberg      97.0  United States            Facebook     5  36.0
# 5   Warren Buffett      96.0  United States  Berkshire Hathaway     6  90.0
#
#                Residence    Citizenship              Status  Children  \
# 0    Seattle, Washington  United States     In Relationship       4.0
# 1          Austin, Texas  United States     In Relationship       7.0
# 3     Medina, Washington  United States            Divorced       3.0
# 4  Palo Alto, California  United States             Married       2.0
# 5        Omaha, Nebraska  United States  Widowed, Remarried       3.0
#
#                                            Education Self_made age_group
# 0     Bachelor of Arts/Science, Princeton University      True     50-70
# 1  Bachelor of Arts/Science, University of Pennsy...      True     30-50
# 3                       Drop Out, Harvard University      True     50-70
# 4                       Drop Out, Harvard University      True     30-50
# 5  Master of Science, Columbia University; Bachel...      True       70+

# %%
df.tail()
# Out:
#                    Name  NetWorth Country        Source  Rank   Age  \
# 2750  Daniel Yong Zhang       1.0   China    e-commerce  2674  49.0
# 2751      Zhang Yuqiang       1.0   China    Fiberglass  2674  65.0
# 2752      Zhao Meiguang       1.0   China   gold mining  2674  58.0
# 2753     Zhong Naixiong       1.0   China  conglomerate  2674  58.0
# 2754    Zhou Wei family       1.0   China      Software  2674  54.0
#
#              Residence Citizenship   Status  Children Education Self_made  \
# 2750   Hangzhou, China       China      NaN       NaN       NaN      True
# 2751  Tongxiang, China       China      NaN       NaN       NaN      True
# 2752      Jilin, China       China      NaN       NaN       NaN      True
# 2753     Foshan, China       China      NaN       NaN       NaN      True
# 2754   Shanghai, China       China  Married       NaN       NaN      True
#
#      age_group
# 2750     30-50
# 2751     50-70
# 2752     50-70
# 2753     50-70
# 2754     50-70

# %%
df.max()
# Out:
# Name         Zygmunt Solorz-Zak
# NetWorth                  177.0
# Country                Zimbabwe
# Source                        ★
# Rank                       2674
# Age                        99.0
# Children                   23.0
# Self_made                  True
# age_group                   70+
# dtype: object

# %%
df.min()
# Out:
# Name         A. Jayson Adair
# NetWorth                 1.0
# Country              Algeria
# Source           3D printing
# Rank                       1
# Age                     18.0
# Children                 1.0
# Self_made              False
# age_group              18-30
# dtype: object

# %%
# plotting data on chart
plt.pie(us_df['NetWorth'], labels=us_df['Name'], colors=palette_color,
        explode=explode, autopct='%.0f%%')
  
# displaying chart
plt.show()

# %% [markdown]
# ## Top Billionares from china

# %%
china = df[df['Country'] == 'China'].sort_values('NetWorth',ascending=False).head()
china
# Out:
#                  Name  NetWorth Country                      Source  Rank  \
# 12     Zhong Shanshan      68.9   China  beverages, pharmaceuticals    13
# 14         Ma Huateng      65.8   China              internet media    15
# 20  Colin Zheng Huang      55.3   China                  e-commerce    21
# 25            Jack Ma      48.4   China                  e-commerce    26
# 34           Wang Wei      39.0   China            package delivery    35
#
#      Age        Residence Citizenship   Status  Children  \
# 12  66.0  Hangzhou, China       China      NaN       NaN
# 14  49.0  Shenzhen, China       China  Married       NaN
# 20  41.0  Shanghai, China       China      NaN       NaN
# 25  56.0  Hangzhou, China       China  Married       NaN
# 34  50.0  Shenzhen, China       China      NaN       NaN
#
#                                             Education Self_made age_group
# 12                                                NaN      True     50-70
# 14      Bachelor of Arts/Science, Shenzhen University      True     30-50
# 20  Master, University of Wisconsin Madison; Bache...      True     30-50
# 25  Bachelor of Arts/Science, Hangzhou Teacher's I...      True     50-70
# 34                                                NaN      True     30-50

# %%
plt.pie(china['NetWorth'], labels=china['Name'], colors=palette_color,
        explode=explode, autopct='%.0f%%')
  
# displaying chart
plt.show()

# %%
df.columns
# Out:
# Index(['Name', 'NetWorth', 'Country', 'Source', 'Rank', 'Age', 'Residence',
#        'Citizenship', 'Status', 'Children', 'Education', 'Self_made',
#        'age_group'],
#       dtype='object')

# %% [markdown]
# ## CODE COMPLETED AND TESTED BY - KOLLURU SAHARSH
# ## PERSONAL PROJECT NAME : - LIST OF BILLIONARES ALL OVER THE COUNTRY
