# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_error
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from scipy.stats import yeojohnson
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
from sklearn.feature_selection import f_regression
from sklearn.preprocessing import LabelEncoder
import warnings
warnings.simplefilter('ignore')
# Out:
# C:\Users\saharsh\anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df = pd.read_csv('creditcard.csv')
df.head(5)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
df.describe().transpose().style.background_gradient(cmap = 'Greens')
# Out:
# <style type="text/css">
# #T_de057_row0_col0, #T_de057_row1_col0, #T_de057_row1_col1, #T_de057_row1_col2, #T_de057_row1_col4, #T_de057_row1_col5, #T_de057_row1_col6, #T_de057_row1_col7, #T_de057_row2_col0, #T_de057_row2_col1, #T_de057_row2_col2, #T_de057_row2_col4, #T_de057_row2_col5, #T_de057_row2_col6, #T_de057_row2_col7, #T_de057_row3_col0, #T_de057_row3_col1, #T_de057_row3_col2, #T_de057_row3_col4, #T_de057_row3_col5, #T_de057_row3_col6, #T_de057_row3_col7, #T_de057_row4_col0, #T_de057_row4_col1, #T_de057_row4_col2, #T_de057_row4_col4, #T_de057_row4_col5, #T_de057_row4_col6, #T_de057_row4_col7, #T_de057_row5_col0, #T_de057_row5_col1, #T_de057_row5_col2, #T_de057_row5_col3, #T_de057_row5_col4, #T_de057_row5_col5, #T_de057_row5_col6, #T_de057_row5_col7, #T_de057_row6_col0, #T_de057_row6_col1, #T_de057_row6_col2, #T_de057_row6_col4, #T_de057_row6_col5, #T_de057_row6_col6, #T_de057_row6_col7, #T_de057_row7_col0, #T_de057_row7_col1, #T_de057_row7_col2, #T_de057_row7_col4, #T_de057_row7_col5, #T_de057_row7_col6, #T_de057_row7_col7, #T_de057_row8_col0, #T_de057_row8_col1, #T_de057_row8_col2, #T_de057_row8_col4, #T_de057_row8_col5, #T_de057_row8_col6, #T_de057_row8_col7, #T_de057_row9_col0, #T_de057_row9_col1, #T_de057_row9_col2, #T_de057_row9_col4, #T_de057_row9_col5, #T_de057_row9_col6, #T_de057_row9_col7, #T_de057_row10_col0, #T_de057_row10_col1, #T_de057_row10_col2, #T_de057_row10_col4, #T_de057_row10_col5, #T_de057_row10_col6, #T_de057_row10_col7, #T_de057_row11_col0, #T_de057_row11_col1, #T_de057_row11_col2, #T_de057_row11_col4, #T_de057_row11_col5, #T_de057_row11_col6, #T_de057_row11_col7, #T_de057_row12_col0, #T_de057_row12_col1, #T_de057_row12_col2, #T_de057_row12_col4, #T_de057_row12_col5, #T_de057_row12_col6, #T_de057_row12_col7, #T_de057_row13_col0, #T_de057_row13_col1, #T_de057_row13_col2, #T_de057_row13_col4, #T_de057_row13_col5, #T_de057_row13_col6, #T_de057_row13_col7, #T_de057_row14_col0, #T_de057_row14_col1, #T_de057_row14_col2, #T_de057_row14_col4, #T_de057_row14_col5, #T_de057_row14_col6, #T_de057_row14_col7, #T_de057_row15_col0, #T_de057_row15_col1, #T_de057_row15_col2, #T_de057_row15_col4, #T_de057_row15_col5, #T_de057_row15_col6, #T_de057_row15_col7, #T_de057_row16_col0, #T_de057_row16_col1, #T_de057_row16_col2, #T_de057_row16_col4, #T_de057_row16_col5, #T_de057_row16_col6, #T_de057_row16_col7, #T_de057_row17_col0, #T_de057_row17_col1, #T_de057_row17_col2, #T_de057_row17_col4, #T_de057_row17_col5, #T_de057_row17_col6, #T_de057_row17_col7, #T_de057_row18_col0, #T_de057_row18_col1, #T_de057_row18_col2, #T_de057_row18_col4, #T_de057_row18_col5, #T_de057_row18_col6, #T_de057_row18_col7, #T_de057_row19_col0, #T_de057_row19_col1, #T_de057_row19_col2, #T_de057_row19_col4, #T_de057_row19_col5, #T_de057_row19_col6, #T_de057_row19_col7, #T_de057_row20_col0, #T_de057_row20_col1, #T_de057_row20_col2, #T_de057_row20_col4, #T_de057_row20_col5, #T_de057_row20_col6, #T_de057_row20_col7, #T_de057_row21_col0, #T_de057_row21_col1, #T_de057_row21_col2, #T_de057_row21_col4, #T_de057_row21_col5, #T_de057_row21_col6, #T_de057_row21_col7, #T_de057_row22_col0, #T_de057_row22_col1, #T_de057_row22_col2, #T_de057_row22_col4, #T_de057_row22_col5, #T_de057_row22_col6, #T_de057_row22_col7, #T_de057_row23_col0, #T_de057_row23_col1, #T_de057_row23_col2, #T_de057_row23_col4, #T_de057_row23_col5, #T_de057_row23_col6, #T_de057_row23_col7, #T_de057_row24_col0, #T_de057_row24_col1, #T_de057_row24_col2, #T_de057_row24_col4, #T_de057_row24_col5, #T_de057_row24_col6, #T_de057_row24_col7, #T_de057_row25_col0, #T_de057_row25_col1, #T_de057_row25_col2, #T_de057_row25_col4, #T_de057_row25_col5, #T_de057_row25_col6, #T_de057_row25_col7, #T_de057_row26_col0, #T_de057_row26_col1, #T_de057_row26_col2, #T_de057_row26_col4, #T_de057_row26_col5, #T_de057_row26_col6, #T_de057_row26_col7, #T_de057_row27_col0, #T_de057_row27_col1, #T_de057_row27_col2, #T_de057_row27_col4, #T_de057_row27_col5, #T_de057_row27_col6, #T_de057_row27_col7, #T_de057_row28_col0, #T_de057_row28_col1, #T_de057_row ...
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_de057_row0_col1, #T_de057_row0_col2, #T_de057_row0_col3, #T_de057_row0_col4, #T_de057_row0_col5, #T_de057_row0_col6, #T_de057_row0_col7, #T_de057_row29_col3, #T_de057_row30_col3 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_de057_row1_col3 {
#   background-color: #72c375;
#   color: #000000;
# }
# #T_de057_row2_col3 {
#   background-color: #a5db9f;
#   color: #000000;
# }
# #T_de057_row3_col3 {
#   background-color: #55b567;
#   color: #f1f1f1;
# }
# #T_de057_row4_col3 {
#   background-color: #005321;
#   color: #f1f1f1;
# }
# #T_de057_row6_col3 {
#   background-color: #1d8640;
#   color: #f1f1f1;
# }
# #T_de057_row7_col3 {
#   background-color: #45ad5f;
#   color: #f1f1f1;
# }
# #T_de057_row8_col3 {
#   background-color: #a7dba0;
#   color: #000000;
# }
# #T_de057_row9_col3 {
#   background-color: #006b2b;
#   color: #f1f1f1;
# }
# #T_de057_row10_col3 {
#   background-color: #19833e;
#   color: #f1f1f1;
# }
# #T_de057_row11_col3, #T_de057_row15_col3 {
#   background-color: #005120;
#   color: #f1f1f1;
# }
# #T_de057_row12_col3 {
#   background-color: #0b7734;
#   color: #f1f1f1;
# }
# #T_de057_row13_col3 {
#   background-color: #005522;
#   color: #f1f1f1;
# }
# #T_de057_row14_col3 {
#   background-color: #0c7735;
#   color: #f1f1f1;
# }
# #T_de057_row16_col3 {
#   background-color: #006c2c;
#   color: #f1f1f1;
# }
# #T_de057_row17_col3 {
#   background-color: #1a843f;
#   color: #f1f1f1;
# }
# #T_de057_row18_col3 {
#   background-color: #005f26;
#   color: #f1f1f1;
# }
# #T_de057_row19_col3 {
#   background-color: #005924;
#   color: #f1f1f1;
# }
# #T_de057_row20_col3 {
#   background-color: #6bc072;
#   color: #000000;
# }
# #T_de057_row21_col3 {
#   background-color: #309950;
#   color: #f1f1f1;
# }
# #T_de057_row22_col3 {
#   background-color: #006328;
#   color: #f1f1f1;
# }
# #T_de057_row23_col3 {
#   background-color: #48ae60;
#   color: #f1f1f1;
# }
# #T_de057_row24_col3 {
#   background-color: #004c1e;
#   color: #f1f1f1;
# }
# #T_de057_row25_col3 {
#   background-color: #006227;
#   color: #f1f1f1;
# }
# #T_de057_row26_col3 {
#   background-color: #004a1e;
#   color: #f1f1f1;
# }
# #T_de057_row27_col3 {
#   background-color: #147e3a;
#   color: #f1f1f1;
# }
# #T_de057_row28_col3 {
#   background-color: #026f2e;
#   color: #f1f1f1;
# }
# #T_de057_row29_col2 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_de057_row29_col7 {
#   background-color: #dff3da;
#   color: #000000;
# }
# </style>
# <table id="T_de057">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_de057_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_de057_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_de057_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_de057_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_de057_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_de057_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_de057_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_de057_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_de057_level0_row0" class="row_heading level0 row0" >Time</th>
#       <td id="T_de057_row0_col0" class="data row0 col0" >284807.000000</td>
#       <td id="T_de057_row0_col1" class="data row0 col1" >94813.859575</td>
#       <td id="T_de057_row0_col2" class="data row0 col2" >47488.145955</td>
#       <td id="T_de057_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_de057_row0_col4" class="data row0 col4" >54201.500000</td>
#       <td id="T_de057_row0_col5" class="data row0 col5" >84692.000000</td>
#       <td id="T_de057_row0_col6" class="data row0 col6" >139320.500000<

# %%
df.median()
# Out:
# Time      84692.000000
# V1            0.018109
# V2            0.065486
# V3            0.179846
# V4           -0.019847
# V5           -0.054336
# V6           -0.274187
# V7            0.040103
# V8            0.022358
# V9           -0.051429
# V10          -0.092917
# V11          -0.032757
# V12           0.140033
# V13          -0.013568
# V14           0.050601
# V15           0.048072
# V16           0.066413
# V17          -0.065676
# V18          -0.003636
# V19           0.003735
# V20          -0.062481
# V21          -0.029450
# V22           0.006782
# V23          -0.011193
# V24           0.040976
# V25           0.016594
# V26          -0.052139
# V27           0.001342
# V28           0.011244
# Amount       22.000000
# Class         0.000000
# dtype: float64

# %%
df.skew()
# Out:
# Time      -0.035568
# V1        -3.280667
# V2        -4.624866
# V3        -2.240155
# V4         0.676292
# V5        -2.425901
# V6         1.826581
# V7         2.553907
# V8        -8.521944
# V9         0.554680
# V10        1.187141
# V11        0.356506
# V12       -2.278401
# V13        0.065233
# V14       -1.995176
# V15       -0.308423
# V16       -1.100966
# V17       -3.844914
# V18       -0.259880
# V19        0.109192
# V20       -2.037155
# V21        3.592991
# V22       -0.213258
# V23       -5.875140
# V24       -0.552499
# V25       -0.415793
# V26        0.576693
# V27       -1.170209
# V28       11.192091
# Amount    16.977724
# Class     23.997579
# dtype: float64

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
df = df.drop('id', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2548\3811912180.py in <module>
# ----> 1 df = df.drop('id', axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265         for axis, labels in axes.items():
#    4266             if labels is not None:
# -> 4267                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4268
#    4269         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4310             else:
# -> 4311                 new_axis = axis.drop(labels, errors=errors)
#    4312             indexer = axis.get_indexer(new_axis)
#    4313
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6659         if mask.any():
#    6660             if errors != "ignore":
# -> 6661                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6662             indexer = indexer[~mask]
#    6663         return self.delete(indexer)
#
# KeyError: "['id'] not found in axis"

# %%
df.shape
# Out:
# (284807, 31)

# %% [markdown]
# ## Exploratory Data Analysis

# %%
plt.figure(figsize=(8, 8))
sns.countplot(data = df , x = 'Class')
plt.show()

# %%
df[['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
       'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
       'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28']].boxplot(figsize=(15,5))
plt.grid(False)
plt.show()

# %%
fig, ax = plt.subplots(10, 3, figsize=(15, 20))

sns.distplot(df['V1'],ax=ax[0,0], color = 'red', hist_kws={'color': 'blue'})
sns.distplot(df['V2'],ax=ax[0,1],  color = 'red', hist_kws={'color': 'blue'})
sns.distplot(df['V3'],ax=ax[0,2],  color = 'red', hist_kws={'color': 'blue'})
sns.distplot(df['V4'],ax=ax[1,0],  color = 'red', hist_kws={'color': 'blue'})
sns.distplot(df['V5'],ax=ax[1,1],  color = 'red', hist_kws={'color': 'blue'})
sns.distplot(df['V6'],ax=ax[1,2],  color = 'red', hist_kws={'color': 'blue'})
sns.distplot(df['V7'],ax=ax[2,0],  color = 'red', hist_kws={'color': 'blue'})
sns.distplot(df['V8'],ax=ax[2,1],  color = 'red', hist_kws={'color': 'blue'})
sns.distplot(df['V9'],ax=ax[2,2],  color = 'red', hist_kws={'color': 'blue'})
sns.distplot(df['V10'],ax=ax[3,0],  color = 'red', hist_kws={'color': 'blue'})
sns.distplot(df['V11'],ax=ax[3,1],  color = 'red', hist_kws={'color': 'blue'})
sns.distplot(df['V12'],ax=ax[3,2],  color = 'red', hist_kws={'color': 'blue'})
sns.distplot(df['V13'],ax=ax[4,0],  color = 'red', hist_kws={'color': 'blue'})
sns.distplot(df['V14'],ax=ax[4,1],  color = 'red', hist_kws={'color': 'blue'})
sns.distplot(df['V15'],ax=ax[4,2],  color = 'red', hist_kws={'color': 'blue'})
sns.distplot(df['V16'],ax=ax[5,0],  color = 'red', hist_kws={'color': 'blue'})
sns.distplot(df['V17'],ax=ax[5,1],  color = 'red', hist_kws={'color': 'blue'})
sns.distplot(df['V18'],ax=ax[5,2],  color = 'red', hist_kws={'color': 'blue'})
sns.distplot(df['V19'],ax=ax[6,0],  color = 'red', hist_kws={'color': 'blue'})
sns.distplot(df['V20'],ax=ax[6,1],  color = 'red', hist_kws={'color': 'blue'})
sns.distplot(df['V21'],ax=ax[6,2],  color = 'red', hist_kws={'color': 'blue'})
sns.distplot(df['V22'],ax=ax[7,0],  color = 'red', hist_kws={'color': 'blue'})
sns.distplot(df['V23'],ax=ax[7,1],  color = 'red', hist_kws={'color': 'blue'})
sns.distplot(df['V24'],ax=ax[7,2],  color = 'red', hist_kws={'color': 'blue'})
sns.distplot(df['V25'],ax=ax[8,0],  color = 'red', hist_kws={'color': 'blue'})
sns.distplot(df['V26'],ax=ax[8,1],  color = 'red', hist_kws={'color': 'blue'})
sns.distplot(df['V27'],ax=ax[8,2],  color = 'red', hist_kws={'color': 'blue'})
sns.distplot(df['V28'],ax=ax[9,0],  color = 'red', hist_kws={'color': 'blue'})
sns.distplot(df['Amount'],ax=ax[9,1],  color = 'red', hist_kws={'color': 'blue'})

plt.show()

# %%
plt.figure(figsize=(15, 15))
sns.heatmap(df.corr(), annot = True, fmt = '.1f', cmap='Greens')
plt.show()

# %%
X = df.drop(columns=['Class'])
y = df['Class']
f_scores, p_values = f_regression(X,y)

feature_scores_df = pd.DataFrame({'Feature': X.columns, 'F_Score': f_scores, 'P_Value': p_values})
feature_scores_df = feature_scores_df.sort_values(by='F_Score', ascending=False)
feature_scores_df
# Out:
#    Feature       F_Score        P_Value
# 17     V17  33979.168593   0.000000e+00
# 14     V14  28695.547788   0.000000e+00
# 12     V12  20749.822361   0.000000e+00
# 10     V10  14057.979985   0.000000e+00
# 16     V16  11443.349428   0.000000e+00
# 3       V3  11014.508305   0.000000e+00
# 7       V7  10349.605408   0.000000e+00
# 11     V11   6999.355047   0.000000e+00
# 4       V4   5163.832114   0.000000e+00
# 18     V18   3584.380605   0.000000e+00
# 1       V1   2955.668946   0.000000e+00
# 9       V9   2746.600273   0.000000e+00
# 5       V5   2592.357929   0.000000e+00
# 2       V2   2393.401678   0.000000e+00
# 6       V6    543.510578  4.213111e-120
# 21     V21    465.916251  3.002269e-103
# 19     V19    344.990997   5.801517e-77
# 20     V20    114.999731   7.964292e-27
# 8       V8    112.548287   2.740673e-26
# 27     V27     88.045296   6.441920e-21
# 0     Time     43.252998   4.818269e-11
# 28     V28     25.901405   3.595354e-07
# 24     V24     14.850932   1.163760e-04
# 29  Amount      9.033345   2.651221e-03
# 13     V13      5.947672   1.473734e-02
# 26     V26      5.653653   1.741971e-02
# 15     V15      5.080193   2.420143e-02
# 25     V25      3.116062   7.752501e-02
# 23     V23      2.053476   1.518602e-01
# 22     V22      0.184706   6.673597e-01

# %%
ig, ax = plt.subplots(1, 2, figsize=(15, 15))

ax[0].barh(feature_scores_df['Feature'], feature_scores_df['F_Score'], color='skyblue')
ax[0].set_xlabel('Puntaje F')
ax[0].set_ylabel('Característica')
ax[0].set_title('Puntajes F para Características')


ax[1].barh(feature_scores_df['Feature'], -np.log10(feature_scores_df['P_Value']), color='lightcoral')
ax[1].set_xlabel('-log10(P-Value)')
ax[1].set_ylabel('Característica')
ax[1].set_title('Valores p (-log10) para Características')

ax[0].invert_yaxis()
ax[1].invert_yaxis()
plt.show()

# %%
cols = feature_scores_df[feature_scores_df['F_Score']>=0].Feature.to_list()
X_M = df[cols]
X_M.head(1)
# Out:
#         V17       V14       V12       V10       V16        V3        V7  \
# 0  0.207971 -0.311169 -0.617801  0.090794 -0.470401  2.536347  0.239599
#
#       V11        V4       V18  ...  Time       V28       V24  Amount      V13  \
# 0 -0.5516  1.378155  0.025791  ...   0.0 -0.021053  0.066928  149.62 -0.99139
#
#         V26       V15       V25       V23       V22
# 0 -0.189115  1.468177  0.128539 -0.110474  0.277838
#
# [1 rows x 30 columns]

# %% [markdown]
# # Modeling and Evaluation

# %%
X_transformed = X_M.apply(lambda x: yeojohnson(x)[0])
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_transformed)

# %% [markdown]
# # # Train Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# %% [markdown]
# ## Logistic Regression

# %%
logistic_model = LogisticRegression(random_state=42)
logistic_model.fit(X_train, y_train)
logistic_model.score(X_train, y_train)
model_pred_L = logistic_model.predict(X_test)

print(classification_report(y_test, model_pred_L))
print("accuracy: ",accuracy_score(y_test, model_pred_L))
print("mean_absolute_error: ", mean_absolute_error(y_test, model_pred_L))
print("mean_squared_error: ",mean_squared_error(y_test, model_pred_L))

# %% [markdown]
# ## Random Forest Classifier

# %%
random_forest_model = RandomForestClassifier(random_state=42)
random_forest_model.fit(X_train, y_train)
random_forest_model.score(X_train, y_train)
model_pred_R = random_forest_model.predict(X_test)

print(classification_report(y_test, model_pred_R))
print("accuracy: ",accuracy_score(y_test, model_pred_R))
print("mean_absolute_error: ",mean_absolute_error(y_test, model_pred_R))
print("mean_squared_error: ",mean_squared_error(y_test, model_pred_R))

# %% [markdown]
# ## Decision Tree

# %%
decision_tree_model = DecisionTreeClassifier(random_state=42)
decision_tree_model.fit(X_train, y_train)
decision_tree_model.score(X_train, y_train)
model_pred_T = decision_tree_model.predict(X_test)

print(classification_report(y_test, model_pred_T))
print("accuracy: ",accuracy_score(y_test, model_pred_T))
print("mean_absolute_error: ",mean_absolute_error(y_test, model_pred_T))
print("mean_squared_error: ", mean_squared_error(y_test, model_pred_T))

# %% [markdown]
# ## Kneighbors Classifier

# %%
model_NEG = KNeighborsClassifier(n_neighbors=5)
model_NEG.fit(X_train, y_train)
model_NEG.score(X_train, y_train)
model_NEG_Pred = model_NEG.predict(X_test)

print(classification_report(y_test, model_NEG_Pred))
print("accuracy: ",accuracy_score(y_test, model_NEG_Pred))
print("mean_absolute_error: ",mean_absolute_error(y_test, model_NEG_Pred))
print("mean_squared_error: ",mean_squared_error(y_test, model_NEG_Pred))

# %%
pip install --upgrade scikit-learn numpy scipy

# %%
pip install threadpoolctl

# %%
RLOG = confusion_matrix(y_test, model_pred_L)
RMFC = confusion_matrix(y_test, model_pred_R)
DSCT = confusion_matrix(y_test, model_pred_T)
NEG = confusion_matrix(y_test, model_NEG_Pred)

fig, axes = plt.subplots(1, 4, figsize=(20, 5))

sns.heatmap(RLOG, annot=True, cmap='Blues', fmt='g', ax=axes[0])
axes[0].set_title('Confusion Matrix - Logistic Regression')
axes[0].set_xlabel('Predicted')
axes[0].set_ylabel('True')

sns.heatmap(RMFC, annot=True, cmap='Blues', fmt='g', ax=axes[1])
axes[1].set_title('Confusion Matrix - Random Forest')
axes[1].set_xlabel('Predicted')
axes[1].set_ylabel('True')

sns.heatmap(DSCT, annot=True, cmap='Blues', fmt='g', ax=axes[2])
axes[2].set_title('Confusion Matrix - DSCT')
axes[2].set_xlabel('Predicted')
axes[2].set_ylabel('True')

sns.heatmap(NEG, annot=True, cmap='Blues', fmt='g', ax=axes[3])
axes[3].set_title('Confusion Matrix - Neighbors')
axes[3].set_xlabel('Predicted')
axes[3].set_ylabel('True')

print(y_test.value_counts())
plt.show()

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 6))

sns.distplot(y_test, label='Real', ax=ax[0], color = 'Green')
sns.distplot(model_pred_L, label='Predicted', ax=ax[0],  color = 'red')

sns.distplot(y_test, label='Real', ax=ax[1], color = 'Green')
sns.distplot(model_pred_R, label='Predicted', ax=ax[1], color = 'red')

sns.distplot(y_test, label='Real', ax=ax[2], color = 'Green')
sns.distplot(model_pred_T, label='Predicted', ax=ax[2], color = 'red')

sns.distplot(y_test, label='Real', ax=ax[3], color = 'Green')
sns.distplot(model_NEG_Pred, label='Predicted', ax=ax[3], color = 'red')


ax[0].set_title('Logistic Regression')
ax[1].set_title('Random Forest')
ax[2].set_title('decision Tree')
ax[3].set_title('Neighbors')

ax[0].legend()
ax[1].legend()
ax[2].legend()
ax[3].legend()

plt.plot()

# %% [markdown]
# # TRY  1

# %%
X_transformed = X_M.apply(lambda x: yeojohnson(x)[0])
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_transformed)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# %%
logistic_model = LogisticRegression(random_state=42)
logistic_model.fit(X_train, y_train)
logistic_model.score(X_train, y_train)
model_pred_L = logistic_model.predict(X_test)

print(classification_report(y_test, model_pred_L))
print("accuracy: ",accuracy_score(y_test, model_pred_L))
print("mean_absolute_error: ",mean_absolute_error(y_test, model_pred_L))
print("mean_squared_error: ",mean_squared_error(y_test, model_pred_L))

# %%
random_forest_model = RandomForestClassifier(random_state=42)
random_forest_model.fit(X_train, y_train)
random_forest_model.score(X_train, y_train)
model_pred_R = random_forest_model.predict(X_test)

print(classification_report(y_test, model_pred_R))
print("accuracy: ",accuracy_score(y_test, model_pred_R))
print("mean_absolute_error: ",mean_absolute_error(y_test, model_pred_R))
print("mean_squared_error: ",mean_squared_error(y_test, model_pred_R))

# %%
decision_tree_model = DecisionTreeClassifier(random_state=42)
decision_tree_model.fit(X_train, y_train)
decision_tree_model.score(X_train, y_train)
model_pred_T = decision_tree_model.predict(X_test)

print(classification_report(y_test, model_pred_T))
print("accuracy: ",accuracy_score(y_test, model_pred_T))
print("mean_absolute_error: ",mean_absolute_error(y_test, model_pred_T))
print("mean_squared_error: ",mean_squared_error(y_test, model_pred_T))

# %%
model_NEG = KNeighborsClassifier(n_neighbors=5)
model_NEG.fit(X_train, y_train)
model_NEG.score(X_train, y_train)
model_NEG_Pred = model_NEG.predict(X_test)

print(classification_report(y_test, model_NEG_Pred))
print("accuracy: ",accuracy_score(y_test, model_NEG_Pred))
print("mean_absolute_error: ",mean_absolute_error(y_test, model_NEG_Pred))
print("mean_squared_error: ",mean_squared_error(y_test, model_NEG_Pred))

# %%
RLOG = confusion_matrix(y_test, model_pred_L)
RMFC = confusion_matrix(y_test, model_pred_R)
DSCT = confusion_matrix(y_test, model_pred_T)
NEG = confusion_matrix(y_test, model_NEG_Pred)

fig, axes = plt.subplots(1, 4, figsize=(20, 5))

sns.heatmap(RLOG, annot=True, cmap='Blues', fmt='g', ax=axes[0])
axes[0].set_title('Confusion Matrix - Logistic Regression')
axes[0].set_xlabel('Predicted')
axes[0].set_ylabel('True')

sns.heatmap(RMFC, annot=True, cmap='Blues', fmt='g', ax=axes[1])
axes[1].set_title('Confusion Matrix - Random Forest')
axes[1].set_xlabel('Predicted')
axes[1].set_ylabel('True')

sns.heatmap(DSCT, annot=True, cmap='Blues', fmt='g', ax=axes[2])
axes[2].set_title('Confusion Matrix - DSCT')
axes[2].set_xlabel('Predicted')
axes[2].set_ylabel('True')

sns.heatmap(NEG, annot=True, cmap='Blues', fmt='g', ax=axes[3])
axes[3].set_title('Confusion Matrix - Neighbors')
axes[3].set_xlabel('Predicted')
axes[3].set_ylabel('True')

print(y_test.value_counts())
plt.show()

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 6))

sns.distplot(y_test, label='Real', ax=ax[0], color = 'Green')
sns.distplot(model_pred_L, label='Predicted', ax=ax[0],  color = 'red')

sns.distplot(y_test, label='Real', ax=ax[1], color = 'Green')
sns.distplot(model_pred_R, label='Predicted', ax=ax[1], color = 'red')

sns.distplot(y_test, label='Real', ax=ax[2], color = 'Green')
sns.distplot(model_pred_T, label='Predicted', ax=ax[2], color = 'red')

sns.distplot(y_test, label='Real', ax=ax[3], color = 'Green')
sns.distplot(model_NEG_Pred, label='Predicted', ax=ax[3], color = 'red')


ax[0].set_title('Logistic Regression')
ax[1].set_title('Random Forest')
ax[2].set_title('decision Tree')
ax[3].set_title('Neighbors')

ax[0].legend()
ax[1].legend()
ax[2].legend()
ax[3].legend()

plt.plot()
